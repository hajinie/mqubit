# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import rdFingerprintGenerator
from rdkit.Chem import DataStructs
import numpy as np
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
import matplotlib.pyplot as plt

# %%
# Tanimoto 유사도 행렬 계산 함수
def calculate_tanimoto_similarity(smiles_list):
    generator = rdFingerprintGenerator.GetMorganGenerator(radius=2, fpSize=2048)
    mols = [Chem.MolFromSmiles(smile) for smile in smiles_list]
    fps = [generator.GetFingerprint(mol) for mol in mols]
    n = len(fps)
    similarity_matrix = np.zeros((n, n))
    
    for i in range(n):
        for j in range(n):
            if i != j:
                similarity_matrix[i, j] = DataStructs.TanimotoSimilarity(fps[i], fps[j])
    
    return similarity_matrix

# 계층적 클러스터링 함수
def hierarchical_clustering(smiles_list, top_n=9):
    similarity_matrix = calculate_tanimoto_similarity(smiles_list)
    distance_matrix = 1 - similarity_matrix
    Z = linkage(distance_matrix, 'ward')
    cluster_labels = fcluster(Z, t=top_n, criterion='maxclust')
    
    top_n_smiles = []
    for cluster in range(1, top_n + 1):
        cluster_indices = [i for i, x in enumerate(cluster_labels) if x == cluster]
        top_n_smiles.append([smiles_list[i] for i in cluster_indices])
    
    return top_n_smiles, Z

# %%
# CSV 파일을 읽어옵니다.
df = pd.read_csv('../data/sampled_mix/1.bitter-train-100.csv')

# 'Canonical SMILES' 컬럼의 데이터를 리스트로 변환합니다.
smiles_list = df['Canonical SMILES'].tolist()

# Tanimoto 유사도 행렬 계산 및 계층적 클러스터링 수행
similarity_matrix = calculate_tanimoto_similarity(smiles_list)
top_n_smiles, Z = hierarchical_clustering(smiles_list, top_n=9)

# 덴드로그램 시각화
plt.figure(figsize=(10, 7))
dendrogram(Z, labels=smiles_list, leaf_rotation=90)
plt.show()

# Top 9 클러스터 출력
print(top_n_smiles)
# Out:
# [['Oc1cc(O)c2c(c1)oc(cc2=O)c1ccccc1O', 'Oc1ccc(cc1)c1cc(=O)c2c(o1)cccc2O', 'COc1c(O)cc2c(c1O)c(=O)cc(o2)c1ccc(c(c1)O)O', 'COc1ccc(cc1)c1coc2c(c1=O)ccc(c2)O', 'Oc1ccc2c(c1)oc(=O)cc2', 'Oc1cc(O)c2c(c1)oc(c(c2=O)O)c1cc(O)c(c(c1)O)O', 'Oc1ccc2c(c1)oc(=O)c1c2oc2c1ccc(c2)O', 'COc1ccc2c(c1)oc(cc2=O)c1ccc(cc1)O'], ['Oc1ccc(cc1)c1cc(=O)c2c(o1)cc(cc2O)O'], ['CS(=O)C', 'CNC(=S)N', 'CN(C1CCC2(C(=CCC3C2CCC24C3CCC4C(N(C2)C)C)C1)C)C.Br.Br', 'CC1(O)CCC(CC1)C(O)(C)C.O', 'C=CC1CNC(=S)O1', 'NCCS(=O)(=O)O', '[S-][11C]#N.[Na+]', '[Ca+2].[OH-].[OH-]', 'C1CCn2c(CC1)nnn2', 'N#CCCCC#N', 'OCCN(c1nc(N2CCCCC2)c2c(n1)c(nc(n2)N(CCO)CCO)N1CCCCC1)CCO'], ['CC(c1ccc(cc1)C=NO)C', 'OC(=O)Cc1ccccc1Nc1c(Cl)cccc1Cl', 'S(Cc1ccccc1)Cc1ccccc1', 'Cn1c(=O)n(C)c2c(c1=O)[nH]cn2.[O-]C(=O)C.[Na+]', 'CN(C(CN1c2ccccc2Sc2c1cccc2)C)C', 'CC(Cc1ccccc1)(O)C', 'CCCOc1ccc(cc1N(=O)=O)N(=O)=O', 'O=C(c1ccccn1)c1ccccc1', 'CCOCCc1ccccn1', 'CS(=O)(=O)OCCCNCCCOS(=O)(=O)C.Cc1ccc(cc1)S(=O)(=O)O', 'OC(=O)c1cccnc1Nc1cccc(c1C)Cl', 'CCCNCC(COc1ccccc1C(=O)CCc1ccccc1)O.Cl', 'O=C1NC(=O)NC(=O)C1(C)c1ccccc1', 'O=C1c2ccc(cc2S(=O)(=O)N1C)S(=O)(=O)N', 'CCN(CC(COC(=O)c1ccc(cc1)N)(C)C)CC.Cl', 'Cc1nccc2c1[nH]c1c2cccc1', 'CCCCCCCCCCCC[N+](CCOc1ccccc1)(C)C.[Br-]', 'CC(=O)c1cccc(n1)C(=O)C', 'CC(c1c(C)n(n(c1=O)c1ccccc1)C)C', 'COc1cccc2c1S(=O)(=O)NC2=O', 'c1ccc2c(c1)[nH]cn2', 'N[C@H](C(=O)O)Cc1c[nH]cn1', 'CCCCN(CCN1C(=O)c2c(S1(=O)=O)cccc2)CCCC', 'OC(=O)c1ccccc1Nc1cccc(c1)C(F)(F)F', 'CC(C(C(=O)N1CCCC1)(c1ccccc1)c1ccccc1)CN1CCOCC1.OC(C(C(=O)O)O)C(=O)O'], ['[O-][N+](=O)c1cnc(s1)N', 'O=C1NS(=O)(=O)c2c1ccc(c2)N(=O)=O', '[O-][N+](=O)c1cc([N+](=O)[O-])c(c(c1)[N+](=O)[O-])[O-].[NH4+]', 'Nc1ccc(cc1)S(=O)(=O)c1ccc(cc1)N', '[O-][N+](=O)c1cccc2c1cccc2'], ['n1ccncc1', 'n1ccc(cc1)c1ccncc1', 'c1ccncn1'], ['CC(=O)OCC1OC(OC(=O)C)C(C(C1OC(=O)C)OC(=O)C)OC(=O)C', 'CCC1(CCC(C)C)C(=O)NC(=NC1=O)[O-].[Na+]', 'CCCC(C1(CC=C)C(=O)[N-]C(=O)NC1=O)C.[Na+]', 'CC[C@@H](C(=O)C1=C(O)[C@@]([C@@H](C1=O)CC=C(C)C)(O)C(=O)CC=C(C)C)C', 'CCC(C1(CC)C(=O)NC(=NC1=O)[O-])C.[Na+]', 'CC[C@@H]([C@H](C(=O)O)N)C', 'O=C(OCC[N+](C)(C)C)CCC(=O)OCC[N+](C)(C)C.[Cl-].[Cl-]', 'CCC(=O)OC(COC(=O)CC)COC(=O)CC', 'CC(CC(=O)C1=C(O)[C@@]([C@@H](C1=O)CC=C(C)C)(O)C(=O)CC=C(C)C)C', 'CCC1(C(=O)NC(=NC1=O)[O-])c1ccccc1.[Na+]', 'CCC=C(C1(CC)C(=O)NC(=O)NC1=O)C.[Na]'], ['CN1CCC23C4C1Cc1c3c(OC2C(C=C4)O)c(cc1)OCCN1CCOCC1', 'CCn1cc(C(=O)O)c(=O)c2c1nc(nc2)N1CCNCC1', 'O=C1OCC23C(C1)OC(C2CC(=O)C1(C3CCC2(C31OC3C(=O)OC2c1cocc1)C)C)(C)C', 'OCCN1CCN(CC1)C(=O)Cn1c(=O)sc2c1cc(Cl)cc2.Cl', 'O=C(NC1C(=O)N2C1SCC(=C2C(=O)[O-])CSc1nnc(s1)C)Cn1cnnn1.[Na+]', 'OCC1C(C)CC(=CC1C)C', 'COc1c(N2CCN[C@@H](C2)C)c(F)cc2c1n(cc(c2=O)C(=O)O)C1CC1', 'COc1cccc(c1)C1(O)CCCCC1CN(C)C.Cl', 'CCn1cc(C(=O)O)c(=O)c2c1c(F)c(N1CCNC(C1)C)c(c2)F', 'OC1C=CC2C34C1Oc1c4c(CC2N(CC3)C)ccc1O.Cl', 'OC[C@]1(O)OC[C@H]([C@H]([C@@H]1O)O)O', 'OC1CC2(C)C=CC(=O)C(=C2C2C1C(C)C(=O)O2)C', 'COc1cc2CC3(C(c2cc1OC)c1ccc(c(c1OC3)OC)OC)O', 'Cc1cc(OCCOCC[N+](Cc2ccccc2)(C)C)ccc1C(CC(C)(C)C)(C)C.[Cl-]', 'OS(=O)(=O)O.C=CC1CN2CCC1CC2C(c1ccnc2c1cc(OC)cc2)O', 'COc1ccc2c(c1)[nH]c(n2)S(=O)Cc1ncc(c(c1C)OC)C', 'C=CCC1(C(=O)NC(=O)NC1=O)C1CCC=C1', 'OP(=O)(O)O.Cc1ccc2c(c1)C13CCCCC3C(C2)N(CC1)C', 'C=C1C(=O)OC2C1C(O)C1(C)C(=O)C=CC1C(C2)C', 'O=C1C(C2C(C1(C)CC2)(C)C)S(=O)(=O)[O-].CCN(C(=O)c1ccc[n+](c1)C)CC', 'COc1c(OC)ccc2c1c[n+]1CCc3c(c1c2)cc1c(c3)OCO1', 'OO[C@@H]1CC[C@@]2(CC1=CC[C@@H]1[C@@H]([C@H]2O)OC(=O)C1=C)C', 'CC(=CCN1CCN(CC1)Cc1ccc2c(c1)OCO2)CCC=C(CCC=C(C)C)C', 'CCN(CC(CNc1c2cc(OC)ccc2nc2c1ccc(c2)Cl)O)CC.Cl.Cl'], ['COc1ccc(cc1O)CC(c1ccccc1)C', 'Oc1ccc(cc1)C1COc2c(C1)ccc(c2)O', 'CC(=CCc1c(O)cc(c2c1OC(CC2=O)c1ccc(cc1)O)O)C', 'Oc1cc(O)c2c(c1)[o+]c(c(c2)O)c1ccc(c(c1)O)O', 'CCN(CCOC(=O)c1ccc(cc1)N)CC.O.O', 'CCOC(=O)C(c1c(O)oc2c(c1=O)cccc2)c1c(O)oc2c(c1=O)cccc2', 'OCC1OC(OC(CCc2ccc(cc2)O)C)C(C(C1O)O)O', 'OCc1ccc(cc1)O', 'OCC1OC(Oc2cc3OC(CC(=O)c3c(c2)O)c2ccc(cc2)O)C(C(C1O)O)O', 'CC(=O)Nc1ccc(cc1)O', 'OC(COc1cccc2c1c(=O)cc(o2)C(=O)O)COc1ccc2c(c1)c(=O)cc(o2)C(=O)O', 'COc1c2c(=O)cc(oc2c(c2c1cco2)OC)C']]
